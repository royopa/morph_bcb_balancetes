# %%
import os
import shutil
import pandas as pd
from pathlib import Path

# monta os arquivos em um único arquivo
def merge_arquivos(lista_paths, file_name):
    dfs = []
    for file_path in sorted(lista_paths):
        df = pd.read_csv(file_path, sep=';', skiprows=3, encoding='latin1')
        # remove os caracteres em brancos do nome das colunas
        df.rename(columns=lambda x: x.strip(), inplace=True)
        # transforma o campo saldo em número
        df['SALDO'] = df['SALDO'].str.replace(',','.')
        df['SALDO'] = pd.to_numeric(df['SALDO'])
        # junta em um unico dataframe
        dfs.append(df)

    df = pd.concat(dfs, axis=0, ignore_index=True)
    print(df.shape)
    print(df.columns)

    df.to_csv(os.path.join('bases', file_name))
    return True


def prepare_bases_folder():
    folder_path = os.path.join('bases')

    if not os.path.exists(folder_path):
        Path(folder_path).mkdir(parents=True, exist_ok=True)

    return folder_path

# %%
download_folder = os.path.join('downloads')
prepare_bases_folder()
# Out:
# 'bases'

# %%
files = {
    'BANCOS.CSV':[],
    'CONGLOMERADOS.CSV':[],
    'CONSORCIOS.CSV':[],
    'COOPERATIVAS.CSV':[],
    'LIQUIDACAO.CSV':[],
    'SOCIEDADES.CSV':[],
    'COMBINADOS.CSV':[]
}

# %%
for file_name in sorted(os.listdir(download_folder)):
    file_path = os.path.join(download_folder, file_name)
        
    if not file_path.lower().endswith('.csv'):
        continue

    print(file_name)
    data_base = file_name[:7]
    ano = file_name[:4]
    mes = file_name[4:6]
    print(ano, mes, file_name, file_name[6:])
    files.get(file_name[6:]).append(file_path)
# Out:
# 199501BANCOS.CSV
# 1995 01 199501BANCOS.CSV BANCOS.CSV
# 199501CONGLOMERADOS.CSV
# 1995 01 199501CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199501CONSORCIOS.CSV
# 1995 01 199501CONSORCIOS.CSV CONSORCIOS.CSV
# 199501COOPERATIVAS.CSV
# 1995 01 199501COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199501LIQUIDACAO.CSV
# 1995 01 199501LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199501SOCIEDADES.CSV
# 1995 01 199501SOCIEDADES.CSV SOCIEDADES.CSV
# 199502BANCOS.CSV
# 1995 02 199502BANCOS.CSV BANCOS.CSV
# 199502CONGLOMERADOS.CSV
# 1995 02 199502CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199502CONSORCIOS.CSV
# 1995 02 199502CONSORCIOS.CSV CONSORCIOS.CSV
# 199502COOPERATIVAS.CSV
# 1995 02 199502COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199502LIQUIDACAO.CSV
# 1995 02 199502LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199502SOCIEDADES.CSV
# 1995 02 199502SOCIEDADES.CSV SOCIEDADES.CSV
# 199503BANCOS.CSV
# 1995 03 199503BANCOS.CSV BANCOS.CSV
# 199503CONGLOMERADOS.CSV
# 1995 03 199503CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199503CONSORCIOS.CSV
# 1995 03 199503CONSORCIOS.CSV CONSORCIOS.CSV
# 199503COOPERATIVAS.CSV
# 1995 03 199503COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199503LIQUIDACAO.CSV
# 1995 03 199503LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199503SOCIEDADES.CSV
# 1995 03 199503SOCIEDADES.CSV SOCIEDADES.CSV
# 199504BANCOS.CSV
# 1995 04 199504BANCOS.CSV BANCOS.CSV
# 199504CONGLOMERADOS.CSV
# 1995 04 199504CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199504CONSORCIOS.CSV
# 1995 04 199504CONSORCIOS.CSV CONSORCIOS.CSV
# 199504COOPERATIVAS.CSV
# 1995 04 199504COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199504LIQUIDACAO.CSV
# 1995 04 199504LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199504SOCIEDADES.CSV
# 1995 04 199504SOCIEDADES.CSV SOCIEDADES.CSV
# 199505BANCOS.CSV
# 1995 05 199505BANCOS.CSV BANCOS.CSV
# 199505CONGLOMERADOS.CSV
# 1995 05 199505CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199505CONSORCIOS.CSV
# 1995 05 199505CONSORCIOS.CSV CONSORCIOS.CSV
# 199505COOPERATIVAS.CSV
# 1995 05 199505COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199505LIQUIDACAO.CSV
# 1995 05 199505LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199505SOCIEDADES.CSV
# 1995 05 199505SOCIEDADES.CSV SOCIEDADES.CSV
# 199506BANCOS.CSV
# 1995 06 199506BANCOS.CSV BANCOS.CSV
# 199506CONGLOMERADOS.CSV
# 1995 06 199506CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199506CONSORCIOS.CSV
# 1995 06 199506CONSORCIOS.CSV CONSORCIOS.CSV
# 199506COOPERATIVAS.CSV
# 1995 06 199506COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199506LIQUIDACAO.CSV
# 1995 06 199506LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199506SOCIEDADES.CSV
# 1995 06 199506SOCIEDADES.CSV SOCIEDADES.CSV
# 199507BANCOS.CSV
# 1995 07 199507BANCOS.CSV BANCOS.CSV
# 199507CONGLOMERADOS.CSV
# 1995 07 199507CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199507CONSORCIOS.CSV
# 1995 07 199507CONSORCIOS.CSV CONSORCIOS.CSV
# 199507COOPERATIVAS.CSV
# 1995 07 199507COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199507LIQUIDACAO.CSV
# 1995 07 199507LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199507SOCIEDADES.CSV
# 1995 07 199507SOCIEDADES.CSV SOCIEDADES.CSV
# 199508BANCOS.CSV
# 1995 08 199508BANCOS.CSV BANCOS.CSV
# 199508CONGLOMERADOS.CSV
# 1995 08 199508CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199508CONSORCIOS.CSV
# 1995 08 199508CONSORCIOS.CSV CONSORCIOS.CSV
# 199508COOPERATIVAS.CSV
# 1995 08 199508COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199508LIQUIDACAO.CSV
# 1995 08 199508LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199508SOCIEDADES.CSV
# 1995 08 199508SOCIEDADES.CSV SOCIEDADES.CSV
# 199509BANCOS.CSV
# 1995 09 199509BANCOS.CSV BANCOS.CSV
# 199509CONGLOMERADOS.CSV
# 1995 09 199509CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199509CONSORCIOS.CSV
# 1995 09 199509CONSORCIOS.CSV CONSORCIOS.CSV
# 199509COOPERATIVAS.CSV
# 1995 09 199509COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199509LIQUIDACAO.CSV
# 1995 09 199509LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199509SOCIEDADES.CSV
# 1995 09 199509SOCIEDADES.CSV SOCIEDADES.CSV
# 199510BANCOS.CSV
# 1995 10 199510BANCOS.CSV BANCOS.CSV
# 199510CONGLOMERADOS.CSV
# 1995 10 199510CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199510CONSORCIOS.CSV
# 1995 10 199510CONSORCIOS.CSV CONSORCIOS.CSV
# 199510COOPERATIVAS.CSV
# 1995 10 199510COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199510LIQUIDACAO.CSV
# 1995 10 199510LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199510SOCIEDADES.CSV
# 1995 10 199510SOCIEDADES.CSV SOCIEDADES.CSV
# 199511BANCOS.CSV
# 1995 11 199511BANCOS.CSV BANCOS.CSV
# 199511CONGLOMERADOS.CSV
# 1995 11 199511CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199511CONSORCIOS.CSV
# 1995 11 199511CONSORCIOS.CSV CONSORCIOS.CSV
# 199511COOPERATIVAS.CSV
# 1995 11 199511COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199511LIQUIDACAO.CSV
# 1995 11 199511LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199511SOCIEDADES.CSV
# 1995 11 199511SOCIEDADES.CSV SOCIEDADES.CSV
# 199512BANCOS.CSV
# 1995 12 199512BANCOS.CSV BANCOS.CSV
# 199512CONGLOMERADOS.CSV
# 1995 12 199512CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199512CONSORCIOS.CSV
# 1995 12 199512CONSORCIOS.CSV CONSORCIOS.CSV
# 199512COOPERATIVAS.CSV
# 1995 12 199512COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199512LIQUIDACAO.CSV
# 1995 12 199512LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199512SOCIEDADES.CSV
# 1995 12 199512SOCIEDADES.CSV SOCIEDADES.CSV
# 199601BANCOS.CSV
# 1996 01 199601BANCOS.CSV BANCOS.CSV
# 199601CONGLOMERADOS.CSV
# 1996 01 199601CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199601CONSORCIOS.CSV
# 1996 01 199601CONSORCIOS.CSV CONSORCIOS.CSV
# 199601COOPERATIVAS.CSV
# 1996 01 199601COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199601LIQUIDACAO.CSV
# 1996 01 199601LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199601SOCIEDADES.CSV
# 1996 01 199601SOCIEDADES.CSV SOCIEDADES.CSV
# 199602BANCOS.CSV
# 1996 02 199602BANCOS.CSV BANCOS.CSV
# 199602CONGLOMERADOS.CSV
# 1996 02 199602CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199602CONSORCIOS.CSV
# 1996 02 199602CONSORCIOS.CSV CONSORCIOS.CSV
# 199602COOPERATIVAS.CSV
# 1996 02 199602COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199602LIQUIDACAO.CSV
# 1996 02 199602LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199602SOCIEDADES.CSV
# 1996 02 199602SOCIEDADES.CSV SOCIEDADES.CSV
# 199603BANCOS.CSV
# 1996 03 199603BANCOS.CSV BANCOS.CSV
# 199603CONGLOMERADOS.CSV
# 1996 03 199603CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199603CONSORCIOS.CSV
# 1996 03 199603CONSORCIOS.CSV CONSORCIOS.CSV
# 199603COOPERATIVAS.CSV
# 1996 03 199603COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199603LIQUIDACAO.CSV
# 1996 03 199603LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199603SOCIEDADES.CSV
# 1996 03 199603SOCIEDADES.CSV SOCIEDADES.CSV
# 199604BANCOS.CSV
# 1996 04 199604BANCOS.CSV BANCOS.CSV
# 199604CONGLOMERADOS.CSV
# 1996 04 199604CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199604CONSORCIOS.CSV
# 1996 04 199604CONSORCIOS.CSV CONSORCIOS.CSV
# 199604COOPERATIVAS.CSV
# 1996 04 199604COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199604LIQUIDACAO.CSV
# 1996 04 199604LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199604SOCIEDADES.CSV
# 1996 04 199604SOCIEDADES.CSV SOCIEDADES.CSV
# 199605BANCOS.CSV
# 1996 05 199605BANCOS.CSV BANCOS.CSV
# 199605CONGLOMERADOS.CSV
# 1996 05 199605CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199605CONSORCIOS.CSV
# 1996 05 199605CONSORCIOS.CSV CONSORCIOS.CSV
# 199605COOPERATIVAS.CSV
# 1996 05 199605COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199605LIQUIDACAO.CSV
# 1996 05 199605LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199605SOCIEDADES.CSV
# 1996 05 199605SOCIEDADES.CSV SOCIEDADES.CSV
# 199606BANCOS.CSV
# 1996 06 199606BANCOS.CSV BANCOS.CSV
# 199606CONGLOMERADOS.CSV
# 1996 06 199606CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199606CONSORCIOS.CSV
# 1996 06 199606CONSORCIOS.CSV CONSORCIOS.CSV
# 199606COOPERATIVAS.CSV
# 1996 06 199606COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199606LIQUIDACAO.CSV
# 1996 06 199606LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199606SOCIEDADES.CSV
# 1996 06 199606SOCIEDADES.CSV SOCIEDADES.CSV
# 199607BANCOS.CSV
# 1996 07 199607BANCOS.CSV BANCOS.CSV
# 199607CONGLOMERADOS.CSV
# 1996 07 199607CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199607CONSORCIOS.CSV
# 1996 07 199607CONSORCIOS.CSV CONSORCIOS.CSV
# 199607COOPERATIVAS.CSV
# 1996 07 199607COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199607LIQUIDACAO.CSV
# 1996 07 199607LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199607SOCIEDADES.CSV
# 1996 07 199607SOCIEDADES.CSV SOCIEDADES.CSV
# 199608BANCOS.CSV
# 1996 08 199608BANCOS.CSV BANCOS.CSV
# 199608CONGLOMERADOS.CSV
# 1996 08 199608CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199608CONSORCIOS.CSV
# 1996 08 199608CONSORCIOS.CSV CONSORCIOS.CSV
# 199608COOPERATIVAS.CSV
# 1996 08 199608COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199608LIQUIDACAO.CSV
# 1996 08 199608LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199608SOCIEDADES.CSV
# 1996 08 199608SOCIEDADES.CSV SOCIEDADES.CSV
# 199609BANCOS.CSV
# 1996 09 199609BANCOS.CSV BANCOS.CSV
# 199609CONGLOMERADOS.CSV
# 1996 09 199609CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199609CONSORCIOS.CSV
# 1996 09 199609CONSORCIOS.CSV CONSORCIOS.CSV
# 199609COOPERATIVAS.CSV
# 1996 09 199609COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199609LIQUIDACAO.CSV
# 1996 09 199609LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199609SOCIEDADES.CSV
# 1996 09 199609SOCIEDADES.CSV SOCIEDADES.CSV
# 199610BANCOS.CSV
# 1996 10 199610BANCOS.CSV BANCOS.CSV
# 199610CONGLOMERADOS.CSV
# 1996 10 199610CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199610CONSORCIOS.CSV
# 1996 10 199610CONSORCIOS.CSV CONSORCIOS.CSV
# 199610COOPERATIVAS.CSV
# 1996 10 199610COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199610LIQUIDACAO.CSV
# 1996 10 199610LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199610SOCIEDADES.CSV
# 1996 10 199610SOCIEDADES.CSV SOCIEDADES.CSV
# 199611BANCOS.CSV
# 1996 11 199611BANCOS.CSV BANCOS.CSV
# 199611CONGLOMERADOS.CSV
# 1996 11 199611CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199611CONSORCIOS.CSV
# 1996 11 199611CONSORCIOS.CSV CONSORCIOS.CSV
# 199611COOPERATIVAS.CSV
# 1996 11 199611COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199611LIQUIDACAO.CSV
# 1996 11 199611LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199611SOCIEDADES.CSV
# 1996 11 199611SOCIEDADES.CSV SOCIEDADES.CSV
# 199612BANCOS.CSV
# 1996 12 199612BANCOS.CSV BANCOS.CSV
# 199612CONGLOMERADOS.CSV
# 1996 12 199612CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199612CONSORCIOS.CSV
# 1996 12 199612CONSORCIOS.CSV CONSORCIOS.CSV
# 199612COOPERATIVAS.CSV
# 1996 12 199612COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199612LIQUIDACAO.CSV
# 1996 12 199612LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199612SOCIEDADES.CSV
# 1996 12 199612SOCIEDADES.CSV SOCIEDADES.CSV
# 199701BANCOS.CSV
# 1997 01 199701BANCOS.CSV BANCOS.CSV
# 199701CONGLOMERADOS.CSV
# 1997 01 199701CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199701CONSORCIOS.CSV
# 1997 01 199701CONSORCIOS.CSV CONSORCIOS.CSV
# 199701COOPERATIVAS.CSV
# 1997 01 199701COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199701LIQUIDACAO.CSV
# 1997 01 199701LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199701SOCIEDADES.CSV
# 1997 01 199701SOCIEDADES.CSV SOCIEDADES.CSV
# 199702BANCOS.CSV
# 1997 02 199702BANCOS.CSV BANCOS.CSV
# 199702CONGLOMERADOS.CSV
# 1997 02 199702CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199702CONSORCIOS.CSV
# 1997 02 199702CONSORCIOS.CSV CONSORCIOS.CSV
# 199702COOPERATIVAS.CSV
# 1997 02 199702COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199702LIQUIDACAO.CSV
# 1997 02 199702LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199702SOCIEDADES.CSV
# 1997 02 199702SOCIEDADES.CSV SOCIEDADES.CSV
# 199703BANCOS.CSV
# 1997 03 199703BANCOS.CSV BANCOS.CSV
# 199703CONGLOMERADOS.CSV
# 1997 03 199703CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199703CONSORCIOS.CSV
# 1997 03 199703CONSORCIOS.CSV CONSORCIOS.CSV
# 199703COOPERATIVAS.CSV
# 1997 03 199703COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199703LIQUIDACAO.CSV
# 1997 03 199703LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199703SOCIEDADES.CSV
# 1997 03 199703SOCIEDADES.CSV SOCIEDADES.CSV
# 199704BANCOS.CSV
# 1997 04 199704BANCOS.CSV BANCOS.CSV
# 199704CONGLOMERADOS.CSV
# 1997 04 199704CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199704CONSORCIOS.CSV
# 1997 04 199704CONSORCIOS.CSV CONSORCIOS.CSV
# 199704COOPERATIVAS.CSV
# 1997 04 199704COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199704LIQUIDACAO.CSV
# 1997 04 199704LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199704SOCIEDADES.CSV
# 1997 04 199704SOCIEDADES.CSV SOCIEDADES.CSV
# 199705BANCOS.CSV
# 1997 05 199705BANCOS.CSV BANCOS.CSV
# 199705CONGLOMERADOS.CSV
# 1997 05 199705CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199705CONSORCIOS.CSV
# 1997 05 199705CONSORCIOS.CSV CONSORCIOS.CSV
# 199705COOPERATIVAS.CSV
# 1997 05 199705COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199705LIQUIDACAO.CSV
# 1997 05 199705LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199705SOCIEDADES.CSV
# 1997 05 199705SOCIEDADES.CSV SOCIEDADES.CSV
# 199706BANCOS.CSV
# 1997 06 199706BANCOS.CSV BANCOS.CSV
# 199706CONGLOMERADOS.CSV
# 1997 06 199706CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199706CONSORCIOS.CSV
# 1997 06 199706CONSORCIOS.CSV CONSORCIOS.CSV
# 199706COOPERATIVAS.CSV
# 1997 06 199706COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199706LIQUIDACAO.CSV
# 1997 06 199706LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199706SOCIEDADES.CSV
# 1997 06 199706SOCIEDADES.CSV SOCIEDADES.CSV
# 199707BANCOS.CSV
# 1997 07 199707BANCOS.CSV BANCOS.CSV
# 199707CONGLOMERADOS.CSV
# 1997 07 199707CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199707CONSORCIOS.CSV
# 1997 07 199707CONSORCIOS.CSV CONSORCIOS.CSV
# 199707COOPERATIVAS.CSV
# 1997 07 199707COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199707LIQUIDACAO.CSV
# 1997 07 199707LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199707SOCIEDADES.CSV
# 1997 07 199707SOCIEDADES.CSV SOCIEDADES.CSV
# 199708BANCOS.CSV
# 1997 08 199708BANCOS.CSV BANCOS.CSV
# 199708CONGLOMERADOS.CSV
# 1997 08 199708CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199708CONSORCIOS.CSV
# 1997 08 199708CONSORCIOS.CSV CONSORCIOS.CSV
# 199708COOPERATIVAS.CSV
# 1997 08 199708COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199708LIQUIDACAO.CSV
# 1997 08 199708LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199708SOCIEDADES.CSV
# 1997 08 199708SOCIEDADES.CSV SOCIEDADES.CSV
# 199709BANCOS.CSV
# 1997 09 199709BANCOS.CSV BANCOS.CSV
# 199709CONGLOMERADOS.CSV
# 1997 09 199709CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199709CONSORCIOS.CSV
# 1997 09 199709CONSORCIOS.CSV CONSORCIOS.CSV
# 199709COOPERATIVAS.CSV
# 1997 09 199709COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199709LIQUIDACAO.CSV
# 1997 09 199709LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199709SOCIEDADES.CSV
# 1997 09 199709SOCIEDADES.CSV SOCIEDADES.CSV
# 199710BANCOS.CSV
# 1997 10 199710BANCOS.CSV BANCOS.CSV
# 199710CONGLOMERADOS.CSV
# 1997 10 199710CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199710CONSORCIOS.CSV
# 1997 10 199710CONSORCIOS.CSV CONSORCIOS.CSV
# 199710COOPERATIVAS.CSV
# 1997 10 199710COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199710LIQUIDACAO.CSV
# 1997 10 199710LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199710SOCIEDADES.CSV
# 1997 10 199710SOCIEDADES.CSV SOCIEDADES.CSV
# 199711BANCOS.CSV
# 1997 11 199711BANCOS.CSV BANCOS.CSV
# 199711CONGLOMERADOS.CSV
# 1997 11 199711CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199711CONSORCIOS.CSV
# 1997 11 199711CONSORCIOS.CSV CONSORCIOS.CSV
# 199711COOPERATIVAS.CSV
# 1997 11 199711COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199711LIQUIDACAO.CSV
# 1997 11 199711LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199711SOCIEDADES.CSV
# 1997 11 199711SOCIEDADES.CSV SOCIEDADES.CSV
# 199712BANCOS.CSV
# 1997 12 199712BANCOS.CSV BANCOS.CSV
# 199712CONGLOMERADOS.CSV
# 1997 12 199712CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199712CONSORCIOS.CSV
# 1997 12 199712CONSORCIOS.CSV CONSORCIOS.CSV
# 199712COOPERATIVAS.CSV
# 1997 12 199712COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199712LIQUIDACAO.CSV
# 1997 12 199712LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199712SOCIEDADES.CSV
# 1997 12 199712SOCIEDADES.CSV SOCIEDADES.CSV
# 199801BANCOS.CSV
# 1998 01 199801BANCOS.CSV BANCOS.CSV
# 199801CONGLOMERADOS.CSV
# 1998 01 199801CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199801CONSORCIOS.CSV
# 1998 01 199801CONSORCIOS.CSV CONSORCIOS.CSV
# 199801COOPERATIVAS.CSV
# 1998 01 199801COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199801LIQUIDACAO.CSV
# 1998 01 199801LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199801SOCIEDADES.CSV
# 1998 01 199801SOCIEDADES.CSV SOCIEDADES.CSV
# 199802BANCOS.CSV
# 1998 02 199802BANCOS.CSV BANCOS.CSV
# 199802CONGLOMERADOS.CSV
# 1998 02 199802CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199802CONSORCIOS.CSV
# 1998 02 199802CONSORCIOS.CSV CONSORCIOS.CSV
# 199802COOPERATIVAS.CSV
# 1998 02 199802COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199802LIQUIDACAO.CSV
# 1998 02 199802LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199802SOCIEDADES.CSV
# 1998 02 199802SOCIEDADES.CSV SOCIEDADES.CSV
# 199803BANCOS.CSV
# 1998 03 199803BANCOS.CSV BANCOS.CSV
# 199803CONGLOMERADOS.CSV
# 1998 03 199803CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199803CONSORCIOS.CSV
# 1998 03 199803CONSORCIOS.CSV CONSORCIOS.CSV
# 199803COOPERATIVAS.CSV
# 1998 03 199803COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199803LIQUIDACAO.CSV
# 1998 03 199803LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199803SOCIEDADES.CSV
# 1998 03 199803SOCIEDADES.CSV SOCIEDADES.CSV
# 199804BANCOS.CSV
# 1998 04 199804BANCOS.CSV BANCOS.CSV
# 199804CONGLOMERADOS.CSV
# 1998 04 199804CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199804CONSORCIOS.CSV
# 1998 04 199804CONSORCIOS.CSV CONSORCIOS.CSV
# 199804COOPERATIVAS.CSV
# 1998 04 199804COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199804LIQUIDACAO.CSV
# 1998 04 199804LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199804SOCIEDADES.CSV
# 1998 04 199804SOCIEDADES.CSV SOCIEDADES.CSV
# 199805BANCOS.CSV
# 1998 05 199805BANCOS.CSV BANCOS.CSV
# 199805CONGLOMERADOS.CSV
# 1998 05 199805CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199805CONSORCIOS.CSV
# 1998 05 199805CONSORCIOS.CSV CONSORCIOS.CSV
# 199805COOPERATIVAS.CSV
# 1998 05 199805COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199805LIQUIDACAO.CSV
# 1998 05 199805LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199805SOCIEDADES.CSV
# 1998 05 199805SOCIEDADES.CSV SOCIEDADES.CSV
# 199806BANCOS.CSV
# 1998 06 199806BANCOS.CSV BANCOS.CSV
# 199806CONGLOMERADOS.CSV
# 1998 06 199806CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199806CONSORCIOS.CSV
# 1998 06 199806CONSORCIOS.CSV CONSORCIOS.CSV
# 199806COOPERATIVAS.CSV
# 1998 06 199806COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199806LIQUIDACAO.CSV
# 1998 06 199806LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199806SOCIEDADES.CSV
# 1998 06 199806SOCIEDADES.CSV SOCIEDADES.CSV
# 199807BANCOS.CSV
# 1998 07 199807BANCOS.CSV BANCOS.CSV
# 199807CONGLOMERADOS.CSV
# 1998 07 199807CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199807CONSORCIOS.CSV
# 1998 07 199807CONSORCIOS.CSV CONSORCIOS.CSV
# 199807COOPERATIVAS.CSV
# 1998 07 199807COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199807LIQUIDACAO.CSV
# 1998 07 199807LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199807SOCIEDADES.CSV
# 1998 07 199807SOCIEDADES.CSV SOCIEDADES.CSV
# 199808BANCOS.CSV
# 1998 08 199808BANCOS.CSV BANCOS.CSV
# 199808CONGLOMERADOS.CSV
# 1998 08 199808CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199808CONSORCIOS.CSV
# 1998 08 199808CONSORCIOS.CSV CONSORCIOS.CSV
# 199808COOPERATIVAS.CSV
# 1998 08 199808COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199808LIQUIDACAO.CSV
# 1998 08 199808LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199808SOCIEDADES.CSV
# 1998 08 199808SOCIEDADES.CSV SOCIEDADES.CSV
# 199809BANCOS.CSV
# 1998 09 199809BANCOS.CSV BANCOS.CSV
# 199809CONGLOMERADOS.CSV
# 1998 09 199809CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199809CONSORCIOS.CSV
# 1998 09 199809CONSORCIOS.CSV CONSORCIOS.CSV
# 199809COOPERATIVAS.CSV
# 1998 09 199809COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199809LIQUIDACAO.CSV
# 1998 09 199809LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199809SOCIEDADES.CSV
# 1998 09 199809SOCIEDADES.CSV SOCIEDADES.CSV
# 199810BANCOS.CSV
# 1998 10 199810BANCOS.CSV BANCOS.CSV
# 199810CONGLOMERADOS.CSV
# 1998 10 199810CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199810CONSORCIOS.CSV
# 1998 10 199810CONSORCIOS.CSV CONSORCIOS.CSV
# 199810COOPERATIVAS.CSV
# 1998 10 199810COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199810LIQUIDACAO.CSV
# 1998 10 199810LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199810SOCIEDADES.CSV
# 1998 10 199810SOCIEDADES.CSV SOCIEDADES.CSV
# 199811BANCOS.CSV
# 1998 11 199811BANCOS.CSV BANCOS.CSV
# 199811CONGLOMERADOS.CSV
# 1998 11 199811CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199811CONSORCIOS.CSV
# 1998 11 199811CONSORCIOS.CSV CONSORCIOS.CSV
# 199811COOPERATIVAS.CSV
# 1998 11 199811COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199811LIQUIDACAO.CSV
# 1998 11 199811LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199811SOCIEDADES.CSV
# 1998 11 199811SOCIEDADES.CSV SOCIEDADES.CSV
# 199812BANCOS.CSV
# 1998 12 199812BANCOS.CSV BANCOS.CSV
# 199812CONGLOMERADOS.CSV
# 1998 12 199812CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199812CONSORCIOS.CSV
# 1998 12 199812CONSORCIOS.CSV CONSORCIOS.CSV
# 199812COOPERATIVAS.CSV
# 1998 12 199812COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199812LIQUIDACAO.CSV
# 1998 12 199812LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199812SOCIEDADES.CSV
# 1998 12 199812SOCIEDADES.CSV SOCIEDADES.CSV
# 199901BANCOS.CSV
# 1999 01 199901BANCOS.CSV BANCOS.CSV
# 199901CONGLOMERADOS.CSV
# 1999 01 199901CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199901CONSORCIOS.CSV
# 1999 01 199901CONSORCIOS.CSV CONSORCIOS.CSV
# 199901COOPERATIVAS.CSV
# 1999 01 199901COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199901LIQUIDACAO.CSV
# 1999 01 199901LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199901SOCIEDADES.CSV
# 1999 01 199901SOCIEDADES.CSV SOCIEDADES.CSV
# 199902BANCOS.CSV
# 1999 02 199902BANCOS.CSV BANCOS.CSV
# 199902CONGLOMERADOS.CSV
# 1999 02 199902CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199902CONSORCIOS.CSV
# 1999 02 199902CONSORCIOS.CSV CONSORCIOS.CSV
# 199902COOPERATIVAS.CSV
# 1999 02 199902COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199902LIQUIDACAO.CSV
# 1999 02 199902LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199902SOCIEDADES.CSV
# 1999 02 199902SOCIEDADES.CSV SOCIEDADES.CSV
# 199903BANCOS.CSV
# 1999 03 199903BANCOS.CSV BANCOS.CSV
# 199903CONGLOMERADOS.CSV
# 1999 03 199903CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199903CONSORCIOS.CSV
# 1999 03 199903CONSORCIOS.CSV CONSORCIOS.CSV
# 199903COOPERATIVAS.CSV
# 1999 03 199903COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199903LIQUIDACAO.CSV
# 1999 03 199903LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199903SOCIEDADES.CSV
# 1999 03 199903SOCIEDADES.CSV SOCIEDADES.CSV
# 199904BANCOS.CSV
# 1999 04 199904BANCOS.CSV BANCOS.CSV
# 199904CONGLOMERADOS.CSV
# 1999 04 199904CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199904CONSORCIOS.CSV
# 1999 04 199904CONSORCIOS.CSV CONSORCIOS.CSV
# 199904COOPERATIVAS.CSV
# 1999 04 199904COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199904LIQUIDACAO.CSV
# 1999 04 199904LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199904SOCIEDADES.CSV
# 1999 04 199904SOCIEDADES.CSV SOCIEDADES.CSV
# 199905BANCOS.CSV
# 1999 05 199905BANCOS.CSV BANCOS.CSV
# 199905CONGLOMERADOS.CSV
# 1999 05 199905CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199905CONSORCIOS.CSV
# 1999 05 199905CONSORCIOS.CSV CONSORCIOS.CSV
# 199905COOPERATIVAS.CSV
# 1999 05 199905COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199905LIQUIDACAO.CSV
# 1999 05 199905LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199905SOCIEDADES.CSV
# 1999 05 199905SOCIEDADES.CSV SOCIEDADES.CSV
# 199906BANCOS.CSV
# 1999 06 199906BANCOS.CSV BANCOS.CSV
# 199906CONGLOMERADOS.CSV
# 1999 06 199906CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199906CONSORCIOS.CSV
# 1999 06 199906CONSORCIOS.CSV CONSORCIOS.CSV
# 199906COOPERATIVAS.CSV
# 1999 06 199906COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199906LIQUIDACAO.CSV
# 1999 06 199906LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199906SOCIEDADES.CSV
# 1999 06 199906SOCIEDADES.CSV SOCIEDADES.CSV
# 199907BANCOS.CSV
# 1999 07 199907BANCOS.CSV BANCOS.CSV
# 199907CONGLOMERADOS.CSV
# 1999 07 199907CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199907CONSORCIOS.CSV
# 1999 07 199907CONSORCIOS.CSV CONSORCIOS.CSV
# 199907COOPERATIVAS.CSV
# 1999 07 199907COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199907LIQUIDACAO.CSV
# 1999 07 199907LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199907SOCIEDADES.CSV
# 1999 07 199907SOCIEDADES.CSV SOCIEDADES.CSV
# 199908BANCOS.CSV
# 1999 08 199908BANCOS.CSV BANCOS.CSV
# 199908CONGLOMERADOS.CSV
# 1999 08 199908CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199908CONSORCIOS.CSV
# 1999 08 199908CONSORCIOS.CSV CONSORCIOS.CSV
# 199908COOPERATIVAS.CSV
# 1999 08 199908COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199908LIQUIDACAO.CSV
# 1999 08 199908LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199908SOCIEDADES.CSV
# 1999 08 199908SOCIEDADES.CSV SOCIEDADES.CSV
# 199909BANCOS.CSV
# 1999 09 199909BANCOS.CSV BANCOS.CSV
# 199909CONGLOMERADOS.CSV
# 1999 09 199909CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199909CONSORCIOS.CSV
# 1999 09 199909CONSORCIOS.CSV CONSORCIOS.CSV
# 199909COOPERATIVAS.CSV
# 1999 09 199909COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199909LIQUIDACAO.CSV
# 1999 09 199909LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199909SOCIEDADES.CSV
# 1999 09 199909SOCIEDADES.CSV SOCIEDADES.CSV
# 199910BANCOS.CSV
# 1999 10 199910BANCOS.CSV BANCOS.CSV
# 199910CONGLOMERADOS.CSV
# 1999 10 199910CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199910CONSORCIOS.CSV
# 1999 10 199910CONSORCIOS.CSV CONSORCIOS.CSV
# 199910COOPERATIVAS.CSV
# 1999 10 199910COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199910LIQUIDACAO.CSV
# 1999 10 199910LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199910SOCIEDADES.CSV
# 1999 10 199910SOCIEDADES.CSV SOCIEDADES.CSV
# 199911BANCOS.CSV
# 1999 11 199911BANCOS.CSV BANCOS.CSV
# 199911CONGLOMERADOS.CSV
# 1999 11 199911CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199911CONSORCIOS.CSV
# 1999 11 199911CONSORCIOS.CSV CONSORCIOS.CSV
# 199911COOPERATIVAS.CSV
# 1999 11 199911COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199911LIQUIDACAO.CSV
# 1999 11 199911LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199911SOCIEDADES.CSV
# 1999 11 199911SOCIEDADES.CSV SOCIEDADES.CSV
# 199912BANCOS.CSV
# 1999 12 199912BANCOS.CSV BANCOS.CSV
# 199912CONGLOMERADOS.CSV
# 1999 12 199912CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 199912CONSORCIOS.CSV
# 1999 12 199912CONSORCIOS.CSV CONSORCIOS.CSV
# 199912COOPERATIVAS.CSV
# 1999 12 199912COOPERATIVAS.CSV COOPERATIVAS.CSV
# 199912LIQUIDACAO.CSV
# 1999 12 199912LIQUIDACAO.CSV LIQUIDACAO.CSV
# 199912SOCIEDADES.CSV
# 1999 12 199912SOCIEDADES.CSV SOCIEDADES.CSV
# 200001BANCOS.CSV
# 2000 01 200001BANCOS.CSV BANCOS.CSV
# 200001CONGLOMERADOS.CSV
# 2000 01 200001CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200001CONSORCIOS.CSV
# 2000 01 200001CONSORCIOS.CSV CONSORCIOS.CSV
# 200001COOPERATIVAS.CSV
# 2000 01 200001COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200001LIQUIDACAO.CSV
# 2000 01 200001LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200001SOCIEDADES.CSV
# 2000 01 200001SOCIEDADES.CSV SOCIEDADES.CSV
# 200002BANCOS.CSV
# 2000 02 200002BANCOS.CSV BANCOS.CSV
# 200002CONGLOMERADOS.CSV
# 2000 02 200002CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200002CONSORCIOS.CSV
# 2000 02 200002CONSORCIOS.CSV CONSORCIOS.CSV
# 200002COOPERATIVAS.CSV
# 2000 02 200002COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200002LIQUIDACAO.CSV
# 2000 02 200002LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200002SOCIEDADES.CSV
# 2000 02 200002SOCIEDADES.CSV SOCIEDADES.CSV
# 200003BANCOS.CSV
# 2000 03 200003BANCOS.CSV BANCOS.CSV
# 200003CONGLOMERADOS.CSV
# 2000 03 200003CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200003CONSORCIOS.CSV
# 2000 03 200003CONSORCIOS.CSV CONSORCIOS.CSV
# 200003COOPERATIVAS.CSV
# 2000 03 200003COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200003LIQUIDACAO.CSV
# 2000 03 200003LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200003SOCIEDADES.CSV
# 2000 03 200003SOCIEDADES.CSV SOCIEDADES.CSV
# 200004BANCOS.CSV
# 2000 04 200004BANCOS.CSV BANCOS.CSV
# 200004CONGLOMERADOS.CSV
# 2000 04 200004CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200004CONSORCIOS.CSV
# 2000 04 200004CONSORCIOS.CSV CONSORCIOS.CSV
# 200004COOPERATIVAS.CSV
# 2000 04 200004COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200004LIQUIDACAO.CSV
# 2000 04 200004LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200004SOCIEDADES.CSV
# 2000 04 200004SOCIEDADES.CSV SOCIEDADES.CSV
# 200005BANCOS.CSV
# 2000 05 200005BANCOS.CSV BANCOS.CSV
# 200005CONGLOMERADOS.CSV
# 2000 05 200005CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200005CONSORCIOS.CSV
# 2000 05 200005CONSORCIOS.CSV CONSORCIOS.CSV
# 200005COOPERATIVAS.CSV
# 2000 05 200005COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200005LIQUIDACAO.CSV
# 2000 05 200005LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200005SOCIEDADES.CSV
# 2000 05 200005SOCIEDADES.CSV SOCIEDADES.CSV
# 200006BANCOS.CSV
# 2000 06 200006BANCOS.CSV BANCOS.CSV
# 200006CONGLOMERADOS.CSV
# 2000 06 200006CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200006CONSORCIOS.CSV
# 2000 06 200006CONSORCIOS.CSV CONSORCIOS.CSV
# 200006COOPERATIVAS.CSV
# 2000 06 200006COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200006LIQUIDACAO.CSV
# 2000 06 200006LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200006SOCIEDADES.CSV
# 2000 06 200006SOCIEDADES.CSV SOCIEDADES.CSV
# 200007BANCOS.CSV
# 2000 07 200007BANCOS.CSV BANCOS.CSV
# 200007CONGLOMERADOS.CSV
# 2000 07 200007CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200007CONSORCIOS.CSV
# 2000 07 200007CONSORCIOS.CSV CONSORCIOS.CSV
# 200007COOPERATIVAS.CSV
# 2000 07 200007COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200007LIQUIDACAO.CSV
# 2000 07 200007LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200007SOCIEDADES.CSV
# 2000 07 200007SOCIEDADES.CSV SOCIEDADES.CSV
# 200008BANCOS.CSV
# 2000 08 200008BANCOS.CSV BANCOS.CSV
# 200008CONGLOMERADOS.CSV
# 2000 08 200008CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200008CONSORCIOS.CSV
# 2000 08 200008CONSORCIOS.CSV CONSORCIOS.CSV
# 200008COOPERATIVAS.CSV
# 2000 08 200008COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200008LIQUIDACAO.CSV
# 2000 08 200008LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200008SOCIEDADES.CSV
# 2000 08 200008SOCIEDADES.CSV SOCIEDADES.CSV
# 200009BANCOS.CSV
# 2000 09 200009BANCOS.CSV BANCOS.CSV
# 200009CONGLOMERADOS.CSV
# 2000 09 200009CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200009CONSORCIOS.CSV
# 2000 09 200009CONSORCIOS.CSV CONSORCIOS.CSV
# 200009COOPERATIVAS.CSV
# 2000 09 200009COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200009LIQUIDACAO.CSV
# 2000 09 200009LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200009SOCIEDADES.CSV
# 2000 09 200009SOCIEDADES.CSV SOCIEDADES.CSV
# 200010BANCOS.CSV
# 2000 10 200010BANCOS.CSV BANCOS.CSV
# 200010CONGLOMERADOS.CSV
# 2000 10 200010CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200010CONSORCIOS.CSV
# 2000 10 200010CONSORCIOS.CSV CONSORCIOS.CSV
# 200010COOPERATIVAS.CSV
# 2000 10 200010COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200010LIQUIDACAO.CSV
# 2000 10 200010LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200010SOCIEDADES.CSV
# 2000 10 200010SOCIEDADES.CSV SOCIEDADES.CSV
# 200011BANCOS.CSV
# 2000 11 200011BANCOS.CSV BANCOS.CSV
# 200011CONGLOMERADOS.CSV
# 2000 11 200011CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200011CONSORCIOS.CSV
# 2000 11 200011CONSORCIOS.CSV CONSORCIOS.CSV
# 200011COOPERATIVAS.CSV
# 2000 11 200011COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200011LIQUIDACAO.CSV
# 2000 11 200011LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200011SOCIEDADES.CSV
# 2000 11 200011SOCIEDADES.CSV SOCIEDADES.CSV
# 200012BANCOS.CSV
# 2000 12 200012BANCOS.CSV BANCOS.CSV
# 200012CONGLOMERADOS.CSV
# 2000 12 200012CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200012CONSORCIOS.CSV
# 2000 12 200012CONSORCIOS.CSV CONSORCIOS.CSV
# 200012COOPERATIVAS.CSV
# 2000 12 200012COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200012LIQUIDACAO.CSV
# 2000 12 200012LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200012SOCIEDADES.CSV
# 2000 12 200012SOCIEDADES.CSV SOCIEDADES.CSV
# 200101BANCOS.CSV
# 2001 01 200101BANCOS.CSV BANCOS.CSV
# 200101CONGLOMERADOS.CSV
# 2001 01 200101CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200101CONSORCIOS.CSV
# 2001 01 200101CONSORCIOS.CSV CONSORCIOS.CSV
# 200101COOPERATIVAS.CSV
# 2001 01 200101COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200101LIQUIDACAO.CSV
# 2001 01 200101LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200101SOCIEDADES.CSV
# 2001 01 200101SOCIEDADES.CSV SOCIEDADES.CSV
# 200102BANCOS.CSV
# 2001 02 200102BANCOS.CSV BANCOS.CSV
# 200102CONGLOMERADOS.CSV
# 2001 02 200102CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200102CONSORCIOS.CSV
# 2001 02 200102CONSORCIOS.CSV CONSORCIOS.CSV
# 200102COOPERATIVAS.CSV
# 2001 02 200102COOPERATIVAS.CSV COOPERATIVAS.CSV
# 200102LIQUIDACAO.CSV
# 2001 02 200102LIQUIDACAO.CSV LIQUIDACAO.CSV
# 200102SOCIEDADES.CSV
# 2001 02 200102SOCIEDADES.CSV SOCIEDADES.CSV
# 200103BANCOS.CSV
# 2001 03 200103BANCOS.CSV BANCOS.CSV
# 200103CONGLOMERADOS.CSV
# 2001 03 200103CONGLOMERADOS.CSV CONGLOMERADOS.CSV
# 200103LIQUIDACAO.CSV
# 2001 03 200103LIQUIDACAO.CSV LIQUIDACAO.CSV

# %%
for index_name in files:
    print(index_name)
    file_path = files.get(index_name)
    merge_arquivos(file_path, index_name)
# Out:
# BANCOS.CSV
# ['downloads/199501BANCOS.CSV', 'downloads/199502BANCOS.CSV', 'downloads/199503BANCOS.CSV', 'downloads/199504BANCOS.CSV', 'downloads/199505BANCOS.CSV', 'downloads/199506BANCOS.CSV', 'downloads/199507BANCOS.CSV', 'downloads/199508BANCOS.CSV', 'downloads/199509BANCOS.CSV', 'downloads/199510BANCOS.CSV', 'downloads/199511BANCOS.CSV', 'downloads/199512BANCOS.CSV', 'downloads/199601BANCOS.CSV', 'downloads/199602BANCOS.CSV', 'downloads/199603BANCOS.CSV', 'downloads/199604BANCOS.CSV', 'downloads/199605BANCOS.CSV', 'downloads/199606BANCOS.CSV', 'downloads/199607BANCOS.CSV', 'downloads/199608BANCOS.CSV', 'downloads/199609BANCOS.CSV', 'downloads/199610BANCOS.CSV', 'downloads/199611BANCOS.CSV', 'downloads/199612BANCOS.CSV', 'downloads/199701BANCOS.CSV', 'downloads/199702BANCOS.CSV', 'downloads/199703BANCOS.CSV', 'downloads/199704BANCOS.CSV', 'downloads/199705BANCOS.CSV', 'downloads/199706BANCOS.CSV', 'downloads/199707BANCOS.CSV', 'downloads/199708BANCOS.CSV', 'downloads/199709BANCOS.CSV', 'downloads/199710BANCOS.CSV', 'downloads/199711BANCOS.CSV', 'downloads/199712BANCOS.CSV', 'downloads/199801BANCOS.CSV', 'downloads/199802BANCOS.CSV', 'downloads/199803BANCOS.CSV', 'downloads/199804BANCOS.CSV', 'downloads/199805BANCOS.CSV', 'downloads/199806BANCOS.CSV', 'downloads/199807BANCOS.CSV', 'downloads/199808BANCOS.CSV', 'downloads/199809BANCOS.CSV', 'downloads/199810BANCOS.CSV', 'downloads/199811BANCOS.CSV', 'downloads/199812BANCOS.CSV', 'downloads/199901BANCOS.CSV', 'downloads/199902BANCOS.CSV', 'downloads/199903BANCOS.CSV', 'downloads/199904BANCOS.CSV', 'downloads/199905BANCOS.CSV', 'downloads/199906BANCOS.CSV', 'downloads/199907BANCOS.CSV', 'downloads/199908BANCOS.CSV', 'downloads/199909BANCOS.CSV', 'downloads/199910BANCOS.CSV', 'downloads/199911BANCOS.CSV', 'downloads/199912BANCOS.CSV', 'downloads/200001BANCOS.CSV', 'downloads/200002BANCOS.CSV', 'downloads/200003BANCOS.CSV', 'downloads/200004BANCOS.CSV', 'downloads/200005BANCOS.CSV', 'downloads/200006BANCOS.CSV', 'downloads/200007BANCOS.CSV', 'downloads/200008BANCOS.CSV', 'downloads/200009BANCOS.CSV', 'downloads/200010BANCOS.CSV', 'downloads/200011BANCOS.CSV', 'downloads/200012BANCOS.CSV', 'downloads/200101BANCOS.CSV', 'downloads/200102BANCOS.CSV', 'downloads/200103BANCOS.CSV']
# (1786212, 8)
# Index(['DATA', 'CNPJ', 'NOME INSTITUICAO', 'ATRIBUTO', 'DOCUMENTO', 'CONTA',
#        'NOME CONTA', 'SALDO'],
#       dtype='object')
# CONGLOMERADOS.CSV
# ['downloads/199501CONGLOMERADOS.CSV', 'downloads/199502CONGLOMERADOS.CSV', 'downloads/199503CONGLOMERADOS.CSV', 'downloads/199504CONGLOMERADOS.CSV', 'downloads/199505CONGLOMERADOS.CSV', 'downloads/199506CONGLOMERADOS.CSV', 'downloads/199507CONGLOMERADOS.CSV', 'downloads/199508CONGLOMERADOS.CSV', 'downloads/199509CONGLOMERADOS.CSV', 'downloads/199510CONGLOMERADOS.CSV', 'downloads/199511CONGLOMERADOS.CSV', 'downloads/199512CONGLOMERADOS.CSV', 'downloads/199601CONGLOMERADOS.CSV', 'downloads/199602CONGLOMERADOS.CSV', 'downloads/199603CONGLOMERADOS.CSV', 'downloads/199604CONGLOMERADOS.CSV', 'downloads/199605CONGLOMERADOS.CSV', 'downloads/199606CONGLOMERADOS.CSV', 'downloads/199607CONGLOMERADOS.CSV', 'downloads/199608CONGLOMERADOS.CSV', 'downloads/199609CONGLOMERADOS.CSV', 'downloads/199610CONGLOMERADOS.CSV', 'downloads/199611CONGLOMERADOS.CSV', 'downloads/199612CONGLOMERADOS.CSV', 'downloads/199701CONGLOMERADOS.CSV', 'downloads/199702CONGLOMERADOS.CSV', 'downloads/199703CONGLOMERADOS.CSV', 'downloads/199704CONGLOMERADOS.CSV', 'downloads/199705CONGLOMERADOS.CSV', 'downloads/199706CONGLOMERADOS.CSV', 'downloads/199707CONGLOMERADOS.CSV', 'downloads/199708CONGLOMERADOS.CSV', 'downloads/199709CONGLOMERADOS.CSV', 'downloads/199710CONGLOMERADOS.CSV', 'downloads/199711CONGLOMERADOS.CSV', 'downloads/199712CONGLOMERADOS.CSV', 'downloads/199801CONGLOMERADOS.CSV', 'downloads/199802CONGLOMERADOS.CSV', 'downloads/199803CONGLOMERADOS.CSV', 'downloads/199804CONGLOMERADOS.CSV', 'downloads/199805CONGLOMERADOS.CSV', 'downloads/199806CONGLOMERADOS.CSV', 'downloads/199807CONGLOMERADOS.CSV', 'downloads/199808CONGLOMERADOS.CSV', 'downloads/199809CONGLOMERADOS.CSV', 'downloads/199810CONGLOMERADOS.CSV', 'downloads/199811CONGLOMERADOS.CSV', 'downloads/199812CONGLOMERADOS.CSV', 'downloads/199901CONGLOMERADOS.CSV', 'downloads/199902CONGLOMERADOS.CSV', 'downloads/199903CONGLOMERADOS.CSV', 'downloads/199904CONGLOMERADOS.CSV', 'downloads/199905CONGLOMERADOS.CSV', 'downloads/199906CONGLOMERADOS.CSV', 'downloads/199907CONGLOMERADOS.CSV', 'downloads/199908CONGLOMERADOS.CSV', 'downloads/199909CONGLOMERADOS.CSV', 'downloads/199910CONGLOMERADOS.CSV', 'downloads/199911CONGLOMERADOS.CSV', 'downloads/199912CONGLOMERADOS.CSV', 'downloads/200001CONGLOMERADOS.CSV', 'downloads/200002CONGLOMERADOS.CSV', 'downloads/200003CONGLOMERADOS.CSV', 'downloads/200004CONGLOMERADOS.CSV', 'downloads/200005CONGLOMERADOS.CSV', 'downloads/200006CONGLOMERADOS.CSV', 'downloads/200007CONGLOMERADOS.CSV', 'downloads/200008CONGLOMERADOS.CSV', 'downloads/200009CONGLOMERADOS.CSV', 'downloads/200010CONGLOMERADOS.CSV', 'downloads/200011CONGLOMERADOS.CSV', 'downloads/200012CONGLOMERADOS.CSV', 'downloads/200101CONGLOMERADOS.CSV', 'downloads/200102CONGLOMERADOS.CSV', 'downloads/200103CONGLOMERADOS.CSV']
# (958021, 11)
# Index(['#DATA_BASE', 'DOCUMENTO', 'CNPJ', 'AGENCIA', 'NOME_INSTITUICAO',
#        'COD_CONGL', 'NOME_CONGL', 'TAXONOMIA', 'CONTA', 'NOME_CONTA', 'SALDO'],
#       dtype='object')
# CONSORCIOS.CSV
# ['downloads/199501CONSORCIOS.CSV', 'downloads/199502CONSORCIOS.CSV', 'downloads/199503CONSORCIOS.CSV', 'downloads/199504CONSORCIOS.CSV', 'downloads/199505CONSORCIOS.CSV', 'downloads/199506CONSORCIOS.CSV', 'downloads/199507CONSORCIOS.CSV', 'downloads/199508CONSORCIOS.CSV', 'downloads/199509CONSORCIOS.CSV', 'downloads/199510CONSORCIOS.CSV', 'downloads/199511CONSORCIOS.CSV', 'downloads/199512CONSORCIOS.CSV', 'downloads/199601CONSORCIOS.CSV', 'downloads/199602CONSORCIOS.CSV', 'downloads/199603CONSORCIOS.CSV', 'downloads/199604CONSORCIOS.CSV', 'downloads/199605CONSORCIOS.CSV', 'downloads/199606CONSORCIOS.CSV', 'downloads/199607CONSORCIOS.CSV', 'downloads/199608CONSORCIOS.CSV', 'downloads/199609CONSORCIOS.CSV', 'downloads/199610CONSORCIOS.CSV', 'downloads/199611CONSORCIOS.CSV', 'downloads/199612CONSORCIOS.CSV', 'downloads/199701CONSORCIOS.CSV', 'downloads/199702CONSORCIOS.CSV', 'downloads/199703CONSORCIOS.CSV', 'downloads/199704CONSORCIOS.CSV', 'downloads/199705CONSORCIOS.CSV', 'downloads/199706CONSORCIOS.CSV', 'downloads/199707CONSORCIOS.CSV', 'downloads/199708CONSORCIOS.CSV', 'downloads/199709CONSORCIOS.CSV', 'downloads/199710CONSORCIOS.CSV', 'downloads/199711CONSORCIOS.CSV', 'downloads/199712CONSORCIOS.CSV', 'downloads/199801CONSORCIOS.CSV', 'downloads/199802CONSORCIOS.CSV', 'downloads/199803CONSORCIOS.CSV', 'downloads/199804CONSORCIOS.CSV', 'downloads/199805CONSORCIOS.CSV', 'downloads/199806CONSORCIOS.CSV', 'downloads/199807CONSORCIOS.CSV', 'downloads/199808CONSORCIOS.CSV', 'downloads/199809CONSORCIOS.CSV', 'downloads/199810CONSORCIOS.CSV', 'downloads/199811CONSORCIOS.CSV', 'downloads/199812CONSORCIOS.CSV', 'downloads/199901CONSORCIOS.CSV', 'downloads/199902CONSORCIOS.CSV', 'downloads/199903CONSORCIOS.CSV', 'downloads/199904CONSORCIOS.CSV', 'downloads/199905CONSORCIOS.CSV', 'downloads/199906CONSORCIOS.CSV', 'downloads/199907CONSORCIOS.CSV', 'downloads/199908CONSORCIOS.CSV', 'downloads/199909CONSORCIOS.CSV', 'downloads/199910CONSORCIOS.CSV', 'downloads/199911CONSORCIOS.CSV', 'downloads/199912CONSORCIOS.CSV', 'downloads/200001CONSORCIOS.CSV', 'downloads/200002CONSORCIOS.CSV', 'downloads/200003CONSORCIOS.CSV', 'downloads/200004CONSORCIOS.CSV', 'downloads/200005CONSORCIOS.CSV', 'downloads/200006CONSORCIOS.CSV', 'downloads/200007CONSORCIOS.CSV', 'downloads/200008CONSORCIOS.CSV', 'downloads/200009CONSORCIOS.CSV', 'downloads/200010CONSORCIOS.CSV', 'downloads/200011CONSORCIOS.CSV', 'downloads/200012CONSORCIOS.CSV', 'downloads/200101CONSORCIOS.CSV', 'downloads/200102CONSORCIOS.CSV']
